# %% [markdown]
# # Exercise 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,100,11)
y = x**2

# %%
'''fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Title')'''
# Out:
# Text(0.5,1,'Title')

# %%
'''

fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2])

ax1.plot(x,y)
ax2.plot(y,x)'''
# Out:
# '\n\nfig = plt.figure()\n\nax1 = fig.add_axes([0,0,1,1])\nax2 = fig.add_axes([0.2,0.5,0.2,0.2])\n\nax1.plot(x,y)\nax2.plot(y,x)'

# %%
'''x = np.linspace(0,1,11)
y = x**2
z = x **3

fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.4,0.4])

ax1.plot(x,y,z, color='purple',ls='--',lw = 5,marker='1',ms=20)
ax2.plot(y,z,x,color = 'red', lw=8,ls =':',marker='+')

ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('Title')
ax1.set_xlim(0.2)
ax1.set_ylim(0.5)

ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Zoom')
'''
# Out:
# Text(0.5,1,'Zoom')

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(10,2))
ax[0].plot(x,y,color='blue',lw=5)
ax[1].plot(y,x,color='red',ls='--')
